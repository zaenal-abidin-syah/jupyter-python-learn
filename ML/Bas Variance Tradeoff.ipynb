# %%
from luwiji.bias_variance_tradeoff import illustration, demo

# %% [markdown]
# the Priciple of bias variance tradeoff
#
# More complex model --> low bias,but high variance --> prone to overfit
#
# more simple model --> low variance, but high bias --> prone to underfit

# %%
illustration.bias_variance_tradeoff

# %%
illustration.just_right

# %% [markdown]
# # Contoh Analisis
#
# Linear regression => less feature => less Complex => Prone to underfit
#
# Polynomial regression => more feature => more complex => prone to overfit

# %% [markdown]
# # using bias variance tradeoff in tuning

# %% [markdown]
# ## KNN - n-Neighbor

# %%
demo.knn()
# Out:
# interactive(children=(IntSlider(value=1, description='N', max=50, min=1, step=2), Output()), _dom_classes=('wi…

# %% [markdown]
# ### SVM - Kernel

# %%
demo.svm_kernel()

# %% [markdown]
# ### SVM - Penalty

# %%
demo.svm_c()
# Out:
# interactive(children=(FloatLogSlider(value=0.1, description='C', max=3.0, min=-1.0, step=0.25), Output()), _do…

# %% [markdown]
# ### SVM - Gamma

# %%
demo.svm_gamma()
# Out:
# interactive(children=(FloatLogSlider(value=0.001, description='gamma', max=-0.5, min=-3.0, step=0.25), Output(…
