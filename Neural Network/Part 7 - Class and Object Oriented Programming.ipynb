# %%
class Manusia:
    def __init__(self, warna_rambut, tinggi=150, berat=50):
        self.warna_rambut = warna_rambut
        self.tinggi = tinggi
        self.berat = berat
    def cat_rambut(self, warna):
        self.warna_rambut = warna
        print("rambutnya jadi ", warna)
    def BMI(self):
        return self.berat / self.tinggi ** 2

# %%
zaens = Manusia("putih", 134)

# %%
zaens.warna_rambut
# Out:
# 'putih'

# %%
zaens.tinggi
# Out:
# 134

# %%
zaens.berat
# Out:
# 50

# %%
zaens.cat_rambut("belang")
# Out:
# rambutnya jadi  belang

# %%
zaens.warna_rambut
# Out:
# 'belang'

# %%
zaens.BMI()
# Out:
# 0.002784584539986634

# %% [markdown]
# # Inheritence

# %%
class Mahasiswa(Manusia):
    def __init__(self, warna_rambut, tinggi, berat, universitas):
        super().__init__(warna_rambut, tinggi, berat)
        self.universitas = universitas
    def ganti_universitas(self, universitas):
        self.universitas = universitas

# %%
aku = Mahasiswa("hijau", 140, 54, "utm")

# %% [markdown]
# # Pytorc NN Module

# %%
import torch
from torch import nn

# %%
??nn.Module
# Out:
# Init signature: nn.Module(*args, **kwargs) -> None
# Source:
# class Module:
#     r"""Base class for all neural network modules.
#
#     Your models should also subclass this class.
#
#     Modules can also contain other Modules, allowing to nest them in
#     a tree structure. You can assign the submodules as regular attributes::
#
#         import torch.nn as nn
#         import torch.nn.functional as F
#
#         class Model(nn.Module):
#             def __init__(self) -> None:
#                 super().__init__()
#                 self.conv1 = nn.Conv2d(1, 20, 5)
#                 self.conv2 = nn.Conv2d(20, 20, 5)
#
#             def forward(self, x):
#                 x = F.relu(self.conv1(x))
#                 return F.relu(self.conv2(x))
#
#     Submodules assigned in this way will be registered, and will have their
#     parameters converted too when you call :meth:`to`, etc.
#
#     .. note::
#         As per the example above, an ``__init__()`` call to the parent class
# ...

# %%
class CustomNN(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU(),

            nn.Linear(16, 8),
            nn.ReLU(),

            nn.Linear(8, output_size),
            nn.Sigmoid()
        )
    def forward(self, x):
        return self.fc(x)

# %%
class FaceBiometric(nn.Module):
    def __init__(self, input_size, output_size):
        super().__init__()
        self.fc = nn.Sequential(
            nn.Linear(input_size, 16),
            nn.ReLU()
        )
        self.regresi = nn.Linear(16, 4)
        
        self.classifier = nn.Sequential(
            nn.Linear(16, 4),
            nn.Sigmoid()
        )
    def forward(self, x):
        x = self.fc(x)
        pred_reg = self.regresi(x)
        pred_clf = self.clf(x)
        return pred_reg, pred_clf

# %%
ex_data = torch.rand(100, 7)

# %%
model = CustomNN(7, 1)

# %%
output = model(ex_data)
output
# Out:
# tensor([[0.5284],
#         [0.5304],
#         [0.5332],
#         [0.5425],
#         [0.5334],
#         [0.5357],
#         [0.5311],
#         [0.5324],
#         [0.5347],
#         [0.5312],
#         [0.5298],
#         [0.5353],
#         [0.5326],
#         [0.5243],
#         [0.5386],
#         [0.5341],
#         [0.5237],
#         [0.5404],
#         [0.5256],
#         [0.5308],
#         [0.5359],
#         [0.5337],
#         [0.5339],
#         [0.5335],
#         [0.5320],
#         [0.5180],
#         [0.5299],
#         [0.5322],
#         [0.5291],
#         [0.5347],
#         [0.5327],
#         [0.5253],
#         [0.5347],
#         [0.5359],
#         [0.5243],
#         [0.5270],
#         [0.5255],
#         [0.5299],
#         [0.5378],
#         [0.5281],
#         [0.5309],
#         [0.5266],
#         [0.5267],
#         [0.5410],
#         [0.5261],
#         [0.5336],
#         [0.5279],
#         [0.5271],
#         [0.5299],
#         [0.5276],
# ...
